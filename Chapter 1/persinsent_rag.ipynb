# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
sqlite_index.count()
# Out:
# 85

# %%
results = sqlite_index.search("Can I still join the course after it started?", num_results=5)
[doc["question"] for doc in results]
# Out:
# ['I just discovered the course. Can I still join?',
#  'How do I start using Google Gemini models in the Module 1 notebook through the OpenAI-compatible endpoint?',
#  'I missed the first homework - can I still get a certificate?',
#  'Homework: Why does the content keep changing?',
#  'What happens to code saved in Codespaces if I do not commit it?']

# %%
from rag_helper import RAGBase
from openai import OpenAI
import os

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

assistant = RAGBase(
    index=sqlite_index,
    llm_client=openai_client,
)

# %%
answer = assistant.rag("Can I still join the course after it started?")
print(answer)
# Out:
# Based on the provided information, you can still join the course after it started. However, to receive a certificate, you should be aware of the following conditions:
#
# 1. You need to submit your project while the course is still accepting submissions.
# 2. You need to pass the Capstone project to get the certificate. Completing the homework is not mandatory for the certificate, but it is recommended to reinforce concepts.
#
# Note that if you follow the course in a self-paced mode, you will not be able to receive a certificate. Additionally, peer-reviewing of projects can only be done at the time the course is running.
#
# Considering the provided context, joining the course after it started should not be an issue as long as you can submit your project and pass the Capstone project. You don't need to register for the course beforehand; it's just an indicator of interest.

# %%
sqlite_index.close()
